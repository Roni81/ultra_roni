# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome()
url = "https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3A-1%2Ca%3A%2Cp%3Aall&query=%EB%AC%BC%EB%95%8C&c_id=&c_name=&sm=tab_pge&kin_start=11&kin_age=0"
driver.get(url)
html = driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
soup.select("#main_pack > section > div > ul > li:nth-child(1)")[0].text
# Out:
# '신발 물때 제거 조던 1하이에 물때가 묻었는데 어떻게 지우나요?ㅠㅠ 비싸서 함부로 빨지도 못할거 같은데ㅠㅠ'

# %%
que_title = soup.select("div.question_group > a")

# %%
jisik_in = []
for i in range(0,8):
    for i in titles:
        que_title = i.select("div.question_group > a")[0].text
        jisik_in.append([que_title])
    url = "https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3A-1%2Ca%3A%2Cp%3Aall&query=%EB%AC%BC%EB%95%8C&c_id=&c_name=&sm=tab_pge&kin_start="+str(i)+"1&kin_age=0"
    driver.get(url)
    soup = BeautifulSoup(html,'html.parser')
    titles = soup.select('li.bx._svp_item')
  jisik_in
# Out:
# [['신발 물때 제거 조던 1하이에 물때가 묻었는데 어떻게 지우나요?ㅠㅠ 비싸서 함부로 빨지도 못할거 같은데ㅠㅠ'],
#  ['23년 5월 27일 태안 부근 조개체험 물때 아시는분 ㅠㅠ 아이와 함께 조개체험 하려고 합니다. 조개 종류 상관없이 제목 처럼 저날 언제 조개잡기 가능한 시간 일까요? 펜션 + 물때시간 알려주시는 분께 내공 100 드립니다. 정확한 분께만요 광고는 사절입니다.'],
#  ['이번 주말 제부도 가는데 물때 시간이랑 보는 방법 알려주세요 통행시간표 보는 법도 알려주세요'],
#  ['샴푸의 린스성분도 자동차 본넷에 낀 물때를 제거할수 있나요? 자동차 본넷에 보면 물때가 굉장히 많이 끼어있습니다. 워터스팟을 사용하고 있기는 한데요... 세차를 할때 차에 물을 뿌리고 린스(샴푸)를 스펀지에 뭍혀서 세차를 하면 물때가 조금은 제거가 되나요? 세차를 할때 광택을 낼때 제일 신경쓰이는 것이 물때입니다.'],
#  ['강원도 현재 물때 지금 바다가려는데 물때 좀 알려주세요! 급해요!!'],
#  ['몽산포해수욕장 물때 5일 갯벌체험이랑 해루질 갈려고 합니다 물때 시간 보는 방법을 몰라서요 ㅜ 갯벌체험시간이랑 저녁 해루질 가능한 시간 부탁드려요 ~ 그날 해루질 가능할까요?'],
#  ['여수 선상 문어낚시 물때 질문이요. 21일 여수 문어낚시갈까해요. 비도오는날씨지만 쉬는날이라... 근데 14물때인데 선상타기에 물때 괜찮을까요? 간다면 봉돌은 몇호가 좋을까요?'],
#  ['백조기 물때 질문[내공50] 7/29 ~ 8/6 까지 군산으로 휴가를 가게되어 생활낚시 중 초보자도 쉽게할 수 있다는 백조기 낚시를 할려고하는데 물때보는게 어렵네요 그리고 비온다음은 활성도가 떨어져서 낚시하기 힘들다는데 그것도 날짜를 고르는데 힘들게하네요 어느날짜가 좋을까요?'],
#  ['물때표 보는법(갯벌체험시간) 여기 사진에서 혹시 갯벌체험시간은 몇시부터 몇시정도까지 할 수 있을까요? 물때표 보는법을 몰라서요'],
# ...

# %%
import konlpy
import re

# %%
jisik_in = re.sub('[^가-힣]', ' ', jisik_in)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 jisik_in = re.sub('[^가-힣]', ' ', jisik_in)
#
# File ~\anaconda3\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'list'

# %%
jisik_in_t = sum(jisik_in,[])
jisik_in_t
# Out:
# ['신발 물때 제거 조던 1하이에 물때가 묻었는데 어떻게 지우나요?ㅠㅠ 비싸서 함부로 빨지도 못할거 같은데ㅠㅠ',
#  '23년 5월 27일 태안 부근 조개체험 물때 아시는분 ㅠㅠ 아이와 함께 조개체험 하려고 합니다. 조개 종류 상관없이 제목 처럼 저날 언제 조개잡기 가능한 시간 일까요? 펜션 + 물때시간 알려주시는 분께 내공 100 드립니다. 정확한 분께만요 광고는 사절입니다.',
#  '이번 주말 제부도 가는데 물때 시간이랑 보는 방법 알려주세요 통행시간표 보는 법도 알려주세요',
#  '샴푸의 린스성분도 자동차 본넷에 낀 물때를 제거할수 있나요? 자동차 본넷에 보면 물때가 굉장히 많이 끼어있습니다. 워터스팟을 사용하고 있기는 한데요... 세차를 할때 차에 물을 뿌리고 린스(샴푸)를 스펀지에 뭍혀서 세차를 하면 물때가 조금은 제거가 되나요? 세차를 할때 광택을 낼때 제일 신경쓰이는 것이 물때입니다.',
#  '강원도 현재 물때 지금 바다가려는데 물때 좀 알려주세요! 급해요!!',
#  '몽산포해수욕장 물때 5일 갯벌체험이랑 해루질 갈려고 합니다 물때 시간 보는 방법을 몰라서요 ㅜ 갯벌체험시간이랑 저녁 해루질 가능한 시간 부탁드려요 ~ 그날 해루질 가능할까요?',
#  '여수 선상 문어낚시 물때 질문이요. 21일 여수 문어낚시갈까해요. 비도오는날씨지만 쉬는날이라... 근데 14물때인데 선상타기에 물때 괜찮을까요? 간다면 봉돌은 몇호가 좋을까요?',
#  '백조기 물때 질문[내공50] 7/29 ~ 8/6 까지 군산으로 휴가를 가게되어 생활낚시 중 초보자도 쉽게할 수 있다는 백조기 낚시를 할려고하는데 물때보는게 어렵네요 그리고 비온다음은 활성도가 떨어져서 낚시하기 힘들다는데 그것도 날짜를 고르는데 힘들게하네요 어느날짜가 좋을까요?',
#  '물때표 보는법(갯벌체험시간) 여기 사진에서 혹시 갯벌체험시간은 몇시부터 몇시정도까지 할 수 있을까요? 물때표 보는법을 몰라서요',
# ...

# %%
import numpy as np
from wordcloud import WordCloud
img = np.array(img)
wc = WordCloud(random_state = 1234,         # 난수 고정
               font_path = font,            # 폰트 설정
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white',  # 배경색
               mask = img,                  # mask 설정
               colormap = 'inferno')        # 컬러맵 설정
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[71], line 3
#       1 jisik_in_t = sum(jisik_in,[])
#       2 okt = konlpy.tag.Okt()
# ----> 3 print(okt.pos(jisik_in_t))
#
# File ~\anaconda3\Lib\site-packages\konlpy\tag\_okt.py:69, in Okt.pos(self, phrase, norm, stem, join)
#      58 def pos(self, phrase, norm=False, stem=False, join=False):
#      59     """POS tagger.
#      60     In contrast to other classes in this subpackage,
#      61     this POS tagger doesn't have a `flatten` option,
#    (...)
#      67     :param join: If True, returns joined sets of morph and tag.
#      68     """
# ---> 69     validate_phrase_inputs(phrase)
#      71     tokens = self.jki.tokenize(
#      72                 phrase,
#      73                 jpype.java.lang.Boolean(norm),
#      74                 jpype.java.lang.Boolean(stem)).toArray()
#      75     if join:
#
# ...

# %%
" ".join(jisik_in_t)
# Out:
# '신발 물때 제거 조던 1하이에 물때가 묻었는데 어떻게 지우나요?ㅠㅠ 비싸서 함부로 빨지도 못할거 같은데ㅠㅠ 23년 5월 27일 태안 부근 조개체험 물때 아시는분 ㅠㅠ 아이와 함께 조개체험 하려고 합니다. 조개 종류 상관없이 제목 처럼 저날 언제 조개잡기 가능한 시간 일까요? 펜션 + 물때시간 알려주시는 분께 내공 100 드립니다. 정확한 분께만요 광고는 사절입니다. 이번 주말 제부도 가는데 물때 시간이랑 보는 방법 알려주세요 통행시간표 보는 법도 알려주세요 샴푸의 린스성분도 자동차 본넷에 낀 물때를 제거할수 있나요? 자동차 본넷에 보면 물때가 굉장히 많이 끼어있습니다. 워터스팟을 사용하고 있기는 한데요... 세차를 할때 차에 물을 뿌리고 린스(샴푸)를 스펀지에 뭍혀서 세차를 하면 물때가 조금은 제거가 되나요? 세차를 할때 광택을 낼때 제일 신경쓰이는 것이 물때입니다. 강원도 현재 물때 지금 바다가려는데 물때 좀 알려주세요! 급해요!! 몽산포해수욕장 물때 5일 갯벌체험이랑 해루질 갈려고 합니다 물때 시간 보는 방법을 몰라서요 ㅜ 갯벌체험시간이랑 저녁 해루질 가능한 시간 부탁드려요 ~ 그날 해루질 가능할까요? 여수 선상 문어낚시 물때 질문이요. 21일 여수 문어낚시갈까해요. 비도오는날씨지만 쉬는날이라... 근데 14물때인데 선상타기에 물때 괜찮을까요? 간다면 봉돌은 몇호가 좋을까요? 백조기 물때 질문[내공50] 7/29 ~ 8/6 까지 군산으로 휴가를 가게되어 생활낚시 중 초보자도 쉽게할 수 있다는 백조기 낚시를 할려고하는데 물때보는게 어렵네요 그리고 비온다음은 활성도가 떨어져서 낚시하기 힘들다는데 그것도 날짜를 고르는데 힘들게하네요 어느날짜가 좋을까요? 물때표 보는법(갯벌체험시간) 여기 사진에서 혹시 갯벌체험시간은 몇시부터 몇시정도까지 할 수 있을까요? 물때표 보는법을 몰라서요 네이버지도 앱 물때도 알려주나요? 육지에 파란색으로 덮인 부분은 오류인가요? 물때를 알려주는건가요? 침수라는걸까요 신발 물때 제거 조던 1하이에 물때가 묻었는데 어떻게 지우나요?ㅠㅠ
# ...

# %%
okt = konlpy.tag.Okt()

# %%
res = okt.nouns(" ".join(jisik_in_t))

# %%
import PIL
import pandas as pd
df_res = pd.DataFrame(res)
df_res
df_res['count'] = df_res[0].str.len()
df_res.sort_values('count')
# df_res = df_res.groupby(0, as_index = False).agg(n=(0,'count')).sort_values('n', ascending = False)
# Out:
#          0  count
# 599      때      1
# 921      날      1
# 258      것      1
# 253      때      1
# 913      분      1
# ...    ...    ...
# 628   해수욕장      4
# 808   해수욕장      4
# 1168  해수욕장      4
# 448   해수욕장      4
# 88    해수욕장      4
#
# [1440 rows x 2 columns]

# %%
dic_word = df_res.set_index(0).to_dict()

# %%
dic_word
# Out:
# {'count': {'신발': 2,
#   '물때': 2,
#   '제거': 2,
#   '조던': 2,
#   '하이': 2,
#   '함부로': 3,
#   '태안': 2,
#   '부근': 2,
#   '조개': 2,
#   '체험': 2,
#   '아시': 2,
#   '분': 1,
#   '아이': 2,
#   '종류': 2,
#   '제목': 2,
#   '처럼': 2,
#   '날': 1,
#   '언제': 2,
#   '잡기': 2,
#   '시간': 2,
#   '요': 1,
#   '펜션': 2,
#   '내공': 2,
#   '만요': 2,
#   '광고': 2,
#   '사절': 2,
#   '이번': 2,
#   '주말': 2,
#   '제부도': 3,
#   '방법': 2,
#   '통행': 2,
#   '시간표': 3,
#   '법도': 2,
#   '샴푸': 2,
#   '린스': 2,
#   '성분': 2,
#   '자동차': 3,
#   '본넷': 2,
#   '워터': 2,
#   '스팟': 2,
#   '사용': 2,
#   '세차': 2,
#   '때': 1,
#   '차': 1,
#   '물': 1,
#   '뿌리': 2,
#   '를': 1,
#   '스펀지': 3,
#   '뭍혀': 2,
#   '조금': 2,
#   '광택': 2,
#   '낼때': 2,
#   '제일': 2,
#   '신경': 2,
#   '것': 1,
#   '강원도': 3,
#   '현재': 2,
#   '지금': 2,
#   '바다': 2,
#   '좀': 1,
#   '몽산포': 3,
#   '해수욕장': 4,
#   '갯벌': 2,
#   '해루': 2,
#   '질': 1,
#   '저녁': 2,
#   '그날': 2,
#   '여수': 2,
#   '선상': 2,
#   '문어': 2,
#   '낚시': 2,
#   '질문': 2,
#   '해': 1,
#   '비도': 2,
#   '날씨': 2,
#   '간다': 2,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud
font = "‪‪C:\Windows\Fonts\HMFMPYUN.TTF"
wc = WordCloud(random_state = 1234,         # 난수 고정
               font_path = font,            # 폰트 설정
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white',  # 배경색                 # mask 설정
               colormap = 'inferno')        # 컬러맵 설정

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word['count'])

# %%
plt.figure(figsize = (10,10))
plt.imshow(img_wordcloud)
