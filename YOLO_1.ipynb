# %% [markdown]
# <a href="https://colab.research.google.com/github/Roni81/ultra_roni/blob/main/YOLO_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
from IPython.display import Image

# %%
image1 = Image(filename = "/NewJeans-X-MUSINSA-2022-documents-1.jpeg")

# %%
image1

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 70.4MB/s]

# %%
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
model.predict(source="/NewJeans-X-MUSINSA-2022-documents-1.jpeg")
# Out:
# image 1/1 /NewJeans-X-MUSINSA-2022-documents-1.jpeg: 480x640 5 persons, 1 handbag, 355.7ms
# Speed: 21.0ms preprocess, 355.7ms inference, 38.7ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
content_path="/content/drive/MyDrive/"

# %%
results = model.predict(source=content_path+'witcbtp-web-16-9.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/witcbtp-web-16-9.jpg: 352x640 4 persons, 139.6ms
# Speed: 2.8ms preprocess, 139.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0ac921c19f1a> in <cell line: 1>()
# ----> 1 result
#
# NameError: name 'result' is not defined
